# %% [markdown]
# IMPORTING PANDAS

# %%
import pandas as pd

# %% [markdown]
# LOADING CSV FILE

# %%
df = pd.read_csv('/01.Data Cleaning and Preprocessing.csv')

# %% [markdown]
# VIEW DATA

# %%
df
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %% [markdown]
# OPERATIONS ON DATA

# %%
print(df.head())
# Out:
#   Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0    31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1    31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2    31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3    31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4    31-04:00    22.90    15.618      93.244  1334.168      243.131
#
#    T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 0        358.282         329.545  1.443       599.253  ...        67.122
# 1        351.050         329.067  1.549       537.201  ...        60.012
# 2        350.022         329.260  1.600       549.611  ...        61.304
# 3        350.938         331.142  1.604       623.362  ...        68.496
# 4        351.640         332.709    NaN       638.672  ...        70.022
#
#    Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# ...

# %%
df.tail()
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 312    31-10:00    24.40    14.117      85.998  1330.104      394.234
# 317     4-16:00    17.80    16.625      78.367  1276.082      202.744
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 312        348.089         319.027  1.429       540.558  ...        62.179
# 317        360.127         329.266  1.488       698.486  ...        75.296
# 319        347.286         310.970  1.523       513.956  ...        61.141
# 320        399.135         319.576  1.451       570.058  ...        67.667
# 322        364.081         308.559  1.523       504.852  ...        61.054
#
#      Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# ...

# %%
df.shape
# Out:
# (141, 23)

# %%
df.columns
# Out:
# Index(['Observation', 'Y-Kappa', 'ChipRate', 'BF-CMratio', 'BlowFlow',
#        'ChipLevel4 ', 'T-upperExt-2 ', 'T-lowerExt-2  ', 'UCZAA',
#        'WhiteFlow-4 ', 'AAWhiteSt-4 ', 'AA-Wood-4  ', 'ChipMoisture-4 ',
#        'SteamFlow-4 ', 'Lower-HeatT-3', 'Upper-HeatT-3 ', 'ChipMass-4 ',
#        'WeakLiquorF ', 'BlackFlow-2 ', 'WeakWashF ', 'SteamHeatF-3 ',
#        'T-Top-Chips-4 ', 'SulphidityL-4 '],
#       dtype='object')

# %% [markdown]
# HANDLING MISSING VALUES

# %%
df.duplicated().sum()
# Out:
# 10

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Observation        0
# Y-Kappa            0
# ChipRate           0
# BF-CMratio         0
# BlowFlow           0
# ChipLevel4         0
# T-upperExt-2       0
# T-lowerExt-2       0
# UCZAA              0
# WhiteFlow-4        0
# AAWhiteSt-4        0
# AA-Wood-4          0
# ChipMoisture-4     0
# SteamFlow-4        0
# Lower-HeatT-3      0
# Upper-HeatT-3      0
# ChipMass-4         0
# WeakLiquorF        0
# BlackFlow-2        0
# WeakWashF          0
# SteamHeatF-3       0
# T-Top-Chips-4      0
# SulphidityL-4      0
# dtype: int64

# %%
df.describe()
# Out:
#           Y-Kappa    ChipRate  BF-CMratio     BlowFlow  ChipLevel4   \
# count  131.000000  131.000000  131.000000   131.000000   131.000000
# mean    20.665725   14.395328   86.793969  1240.197595   265.495664
# std      3.021990    1.496178    7.533255    72.375493    81.847426
# min     12.170000   10.833000   68.645000   954.092000     0.000000
# 25%     18.490000   13.481000   81.164500  1198.625500   220.354000
# 50%     20.700000   14.417000   86.950000  1272.030000   274.516000
# 75%     23.185000   15.529500   92.024500  1289.225000   332.497000
# max     27.600000   16.817000  114.570000  1334.892000   419.014000
#
#        T-upperExt-2   T-lowerExt-2         UCZAA  WhiteFlow-4   AAWhiteSt-4   \
# count     131.000000      131.000000  131.000000    131.000000    131.000000
# mean      356.834206      324.133267    1.497626    595.079710      6.146672
# std         9.403771        7.847815    0.106500     68.208005      0.081359
# ...

# %%
df.nunique()
# Out:
# Observation        131
# Y-Kappa            115
# ChipRate           119
# BF-CMratio         131
# BlowFlow           131
# ChipLevel4         128
# T-upperExt-2       128
# T-lowerExt-2       128
# UCZAA              101
# WhiteFlow-4        130
# AAWhiteSt-4         83
# AA-Wood-4          112
# ChipMoisture-4     128
# SteamFlow-4        129
# Lower-HeatT-3      130
# Upper-HeatT-3      131
# ChipMass-4         130
# WeakLiquorF        126
# BlackFlow-2        130
# WeakWashF          121
# SteamHeatF-3       131
# T-Top-Chips-4      122
# SulphidityL-4      108
# dtype: int64

# %% [markdown]
# FILTERING BASED ON CONDITION

# %%
threshold = 100

# %%
filtered_data = df[df['ChipRate'] > threshold]

# %%
filtered_data
# Out:
# Empty DataFrame
# Columns: [Observation, Y-Kappa, ChipRate, BF-CMratio, BlowFlow, ChipLevel4 , T-upperExt-2 , T-lowerExt-2  , UCZAA, WhiteFlow-4 , AAWhiteSt-4 , AA-Wood-4  , ChipMoisture-4 , SteamFlow-4 , Lower-HeatT-3, Upper-HeatT-3 , ChipMass-4 , WeakLiquorF , BlackFlow-2 , WeakWashF , SteamHeatF-3 , T-Top-Chips-4 , SulphidityL-4 ]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# CALCULATING SUMMARY STATISTICS

# %%
# Calculate mean of a column
mean_value = df['ChipRate'].mean()

# %%
mean_value
# Out:
# 14.39532824427481

# %%
# Calculate median of a column
median_value = df['ChipRate'].median()

# %%
median_value
# Out:
# 14.417

# %%
# Calculate standard deviation of a column
std_deviation = df['ChipRate'].std()

# %%
std_deviation
# Out:
# 1.4961784058714804
